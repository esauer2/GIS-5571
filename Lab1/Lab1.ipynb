# %% [markdown]
# # API Data Pipeline

# %% [markdown]
# ### MN GIS API - Infested Waters Shapefile

# %%
# Import necessary packages
import requests
import json
import zipfile
import io
import pandas as pd
import os

# Set access url
url="https://gisdata.mn.gov/api/3/action/package_show?id=c4be2e23-2c68-47ab-8b12-1b1e6df264fb"

# Pull necessary data
r = requests.get(url, verify=False)
print('Data pulled.')
# Out:
# Data pulled.
# /opt/conda/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gisdata.mn.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
# Convert the data into json, and then into a dataframe and print it
json = r.json()
df = pd.DataFrame.from_dict(json)
df
# Out:
#                                                                        help  \
# author                    https://gisdata.mn.gov/api/3/action/help_show?...
# author_email              https://gisdata.mn.gov/api/3/action/help_show?...
# creator_user_id           https://gisdata.mn.gov/api/3/action/help_show?...
# extras                    https://gisdata.mn.gov/api/3/action/help_show?...
# groups                    https://gisdata.mn.gov/api/3/action/help_show?...
# id                        https://gisdata.mn.gov/api/3/action/help_show?...
# isopen                    https://gisdata.mn.gov/api/3/action/help_show?...
# license_id                https://gisdata.mn.gov/api/3/action/help_show?...
# license_title             https://gisdata.mn.gov/api/3/action/help_show?...
# maintainer                https://gisdata.mn.gov/api/3/action/help_show?...
# maintainer_email          https://gisdata.mn.gov/api/3/action/help_show?...
# metadata_created          https://gisdata.mn.gov/api/3/action/help_show?...
# metadata_modified         https://gisdata.mn.gov/api/3/action/help_show?...
# name                      https://gisdata.mn.gov/api/3/action/help_show?...
# notes                     https://gisdata.mn.gov/api/3/action/help_show?...
# num_resources             https://gisdata.mn.gov/api/3/action/help_show?...
# num_tags                  https://gisdata.mn.gov/api/3/action/help_show?...
# organization              https://gisdata.mn.gov/api/3/action/help_show?...
# owner_org                 https://gisdata.mn.gov/api/3/action/help_show?...
# private                   https://gisdata.mn.gov/api/3/action/help_show?...
# relationships_as_object   https://gisdata.mn.gov/api/3/action/help_show?...
# relationships_as_subject  https://gisdata.mn.gov/api/3/action/help_show?...
# resources                 https://gisdata.mn.gov/api/3/action/help_show?...
# revision_id               https://gisdata.mn.gov/api/3/action/help_show?...
# state                     https://gisdata.mn.gov/api/3/action/help_show?...
# tags                      https://gisdata.mn.gov/api/3/action/help_show?...
# title                     https://gisdata.mn.gov/api/3/action/help_show?...
# type                      https://gisdata.mn.gov/api/3/action/help_show?...
# url                       https://gisdata.mn.gov/api/3/action/help_show?...
# version                   https://gisdata.mn.gov/api/3/action/help_show?...
#
#                           success  \
# author                       True
# author_email                 True
# creator_user_id              True
# extras                       True
# groups                       True
# id                           True
# isopen                       True
# license_id                   True
# license_title                True
# maintainer                   True
# maintainer_email             True
# metadata_created             True
# metadata_modified            True
# name                         True
# notes                        True
# num_resources                True
# num_tags                     True
# organization                 True
# owner_org                    True
# private                      True
# relationships_as_object      True
# relationships_as_subject     True
# resources                    True
# revision_id                  True
# state                        True
# tags                         True
# title                        True
# type                         True
# url                          True
# version                      True
#
#                                                                      result
# author                                                                 None
# author_email                                                           None
# creator_user_id                        61044ca7-ee56-4019-aef7-f7c3b5e06e3a
# extras                    [{'key': 'dsAccessConst', 'value': 'None'}, {'...
# groups                    [{'display_name': 'Environment', 'description'...
# id                                     c4be2e23-2c68-47ab-8b12-1b1e6df264fb
# isopen                                                                False
# license_id                                                     notspecified
# license_title                                         License not specified
# maintainer                                                             None
# maintainer_email                                                       None
# metadata_created                                 2017-02-23T11:01:55.236044
# metadata_modified                                2022-10-07T08:06:30.820213
# name                                             env-listed-infested-waters
# notes                     These are water bodies (lakes, streams/rivers,...
# num_resources                                                             6
# num_tags                                                                 11
# organization              {'description': 'Working with citizens to cons...
# owner_org                              0c5bf59b-2a39-402d-bf12-bbf11cf3f201
# private                                                               False
# relationships_as_object                                                  []
# relationships_as_subject                                                 []
# resources                 [{'mimetype': None, 'cache_url': None, 'hash':...
# revision_id                            ce72a3c1-29dc-4f77-b974-a0476b998229
# state                                                                active
# tags                      [{'vocabulary_id': None, 'state': 'active', 'd...
# title                                                Listed Infested Waters
# type                                                                dataset
# url                                                                    None
# version                                                                None

# %%
# Get details for resources and pull out the shapefile's URL
resources = df.loc['resources']
reso_resu = pd.DataFrame.from_dict(resources['result'])
shape_url = reso_resu.loc[reso_resu['resource_type'] == 'shp']['url'].tolist()
print("Shapefile URL: ", shape_url[0])
# Out:
# Shapefile URL:  https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_dnr/env_listed_infested_waters/shp_env_listed_infested_waters.zip

# %%
# Download the zip file at the URL obtained
file_req = requests.get(shape_url[0])
z = zipfile.ZipFile(io.BytesIO(file_req.content))
z.extractall()

# %% [markdown]
# ### Google API - Nearby Search

# %%
# Find Place Google API
import requests
import pandas as pd
import geopandas as gpd
import json

url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=44.986656%2C-93.258133&radius=1500&type=establishment&keyword=water&key=AIzaSyBMiAF0mPjcALvW7ARsm_ZCP9aXIcPG8DI"

payload= {}
headers = {}

# Use set url to get JSON data
response = requests.request("GET", url, headers=headers, data=payload)
# print(response.text)
text_dat = response.text
results = response.json()["results"]

# %%
df = pd.json_normalize(results)
df
# Out:
#    business_status                                               icon  \
# 0      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#    icon_background_color                                 icon_mask_base_uri  \
# 0                #4B96F3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2                #4DB546  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4                #13B5C7  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5                #4DB546  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6                #4DB546  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                              name  \
# 0                       Twin Cities Water Systems
# 1                     Water Department Management
# 2                    Xcel Energy Water Power Park
# 3                           Surge Water Treatment
# 4                          Minneapolis Water Taxi
# 5                                Water Power Park
# 6                                Water Works Park
# 7                              Clean Water Action
# 8                                      Water Laws
# 9                     NADI water charging station
# 10                         Great Waters Financial
# 11                       Save the Boundary Waters
# 12  Commercial Water Damage Minnesota Minneapolis
#
#                        place_id  rating                    reference   scope  \
# 0   ChIJmaXYl5wys1IR-qZUcdPXk-U     0.0  ChIJmaXYl5wys1IR-qZUcdPXk-U  GOOGLE
# 1   ChIJucivcZwys1IRKdixZc1RaAI     0.0  ChIJucivcZwys1IRKdixZc1RaAI  GOOGLE
# 2   ChIJ6xmCT3sts1IRK2iXrEM21OM     4.8  ChIJ6xmCT3sts1IRK2iXrEM21OM  GOOGLE
# 3   ChIJVVVVVYQys1IRU1OZryKsbLQ     0.0  ChIJVVVVVYQys1IRU1OZryKsbLQ  GOOGLE
# 4   ChIJg21GwkEzs1IRej2aDcz4slU     5.0  ChIJg21GwkEzs1IRej2aDcz4slU  GOOGLE
# 5   ChIJOZMdYXsts1IRDivkxw5AF9Y     4.7  ChIJOZMdYXsts1IRDivkxw5AF9Y  GOOGLE
# 6   ChIJz7rAb6Mts1IRfcaEd3zudiY     4.7  ChIJz7rAb6Mts1IRfcaEd3zudiY  GOOGLE
# 7   ChIJK0uwCGhUVEARZ4VvFiXu92Y     3.2  ChIJK0uwCGhUVEARZ4VvFiXu92Y  GOOGLE
# 8   ChIJIzfMopsys1IRjmEY_bA0yUI     0.0  ChIJIzfMopsys1IRjmEY_bA0yUI  GOOGLE
# 9   ChIJDVQDl-Yzs1IRTyS3yNUC1xY     0.0  ChIJDVQDl-Yzs1IRTyS3yNUC1xY  GOOGLE
# 10  ChIJZ8mSd1Q2s1IRb8CUDQQ3n10     0.0  ChIJZ8mSd1Q2s1IRb8CUDQQ3n10  GOOGLE
# 11  ChIJ2_45sR0ts1IRN9bBU0oM99w     0.0  ChIJ2_45sR0ts1IRN9bBU0oM99w  GOOGLE
# 12  ChIJ-ZDfQ40zs1IR8WWCeo22LRE     5.0  ChIJ-ZDfQ40zs1IR8WWCeo22LRE  GOOGLE
#
#                                                 types  ...  \
# 0   [shopping_mall, point_of_interest, establishment]  ...
# 1                  [point_of_interest, establishment]  ...
# 2   [park, tourist_attraction, point_of_interest, ...  ...
# 3                  [point_of_interest, establishment]  ...
# 4   [tourist_attraction, point_of_interest, establ...  ...
# 5   [park, tourist_attraction, point_of_interest, ...  ...
# 6            [park, point_of_interest, establishment]  ...
# 7                  [point_of_interest, establishment]  ...
# 8                  [point_of_interest, establishment]  ...
# 9          [point_of_interest, health, establishment]  ...
# 10        [finance, point_of_interest, establishment]  ...
# 11                 [point_of_interest, establishment]  ...
# 12  [general_contractor, point_of_interest, establ...  ...
#
#     geometry.location.lat geometry.location.lng  \
# 0               44.980263            -93.266206
# 1               44.978461            -93.265841
# 2               44.983134            -93.254667
# 3               44.983654            -93.269357
# 4               44.993340            -93.270309
# 5               44.982972            -93.256595
# 6               44.981556            -93.261092
# 7               44.978081            -93.263451
# 8               44.978411            -93.267477
# 9               44.977753            -93.265011
# 10              44.980343            -93.274237
# 11              44.999588            -93.250098
# 12              44.979011            -93.274550
#
#     geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                         44.981554                       -93.264674
# 1                         44.979880                       -93.264502
# 2                         44.984997                       -93.253295
# 3                         44.984976                       -93.267968
# 4                         44.994633                       -93.268865
# 5                         44.985219                       -93.254649
# 6                         44.982833                       -93.259803
# 7                         44.979492                       -93.262244
# 8                         44.979757                       -93.266117
# 9                         44.979130                       -93.263638
# 10                        44.981759                       -93.272702
# 11                        45.000975                       -93.248940
# 12                        44.980452                       -93.273068
#
#     geometry.viewport.southwest.lat  geometry.viewport.southwest.lng  \
# 0                         44.978855                       -93.267373
# 1                         44.977181                       -93.267202
# 2                         44.982297                       -93.255995
# 3                         44.982277                       -93.270668
# 4                         44.991933                       -93.271564
# 5                         44.982223                       -93.257349
# 6                         44.980134                       -93.262503
# 7                         44.976792                       -93.264943
# 8                         44.977057                       -93.268817
# 9                         44.976430                       -93.266338
# 10                        44.979060                       -93.275402
# 11                        44.998275                       -93.251640
# 12                        44.977753                       -93.275767
#
#     opening_hours.open_now         plus_code.compound_code  \
# 0                     True  XPJM+4G Minneapolis, Minnesota
# 1                      NaN  XPHM+8P Minneapolis, Minnesota
# 2                     True  XPMW+74 Minneapolis, Minnesota
# 3                      NaN                             NaN
# 4                      NaN  XPVH+8V Minneapolis, Minnesota
# 5                    False  XPMV+59 Minneapolis, Minnesota
# 6                      NaN  XPJQ+JH Minneapolis, Minnesota
# 7                    False  XPHP+6J Minneapolis, Minnesota
# 8                      NaN  XPHJ+9X Minneapolis, Minnesota
# 9                      NaN  XPHM+4X Minneapolis, Minnesota
# 10                   False  XPJG+48 Minneapolis, Minnesota
# 11                     NaN  XPXX+RX Minneapolis, Minnesota
# 12                    True  XPHG+J5 Minneapolis, Minnesota
#
#    plus_code.global_code                                             photos
# 0            86P8XPJM+4G                                                NaN
# 1            86P8XPHM+8P                                                NaN
# 2            86P8XPMW+74  [{'height': 3024, 'html_attributions': ['<a hr...
# 3                    NaN                                                NaN
# 4            86P8XPVH+8V  [{'height': 2160, 'html_attributions': ['<a hr...
# 5            86P8XPMV+59  [{'height': 1366, 'html_attributions': ['<a hr...
# 6            86P8XPJQ+JH  [{'height': 3024, 'html_attributions': ['<a hr...
# 7            86P8XPHP+6J                                                NaN
# 8            86P8XPHJ+9X                                                NaN
# 9            86P8XPHM+4X                                                NaN
# 10           86P8XPJG+48  [{'height': 680, 'html_attributions': ['<a hre...
# 11           86P8XPXX+RX                                                NaN
# 12           86P8XPHG+J5  [{'height': 1600, 'html_attributions': ['<a hr...
#
# [13 rows x 22 columns]

# %%
# Use Pandas
#df = pd.DataFrame(results, columns = ('Place','Latitude','Longitude'))

#for x in range(len(results)):
#   Place = [x]['results']['name']
#    Latitude = [x]['geometry']['location']['lat']
#        Longitude = [x]['geometry']['location']['lng']

# %%
df.rename(columns = {'geometry.location.lat':'Latitude'}, inplace = True)
df.rename(columns = {'geometry.location.lng':'Longitude'}, inplace = True)
df

gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Latitude, df.Longitude), crs = 26915)
# google_shp = gdf.to_file('google_loc.shp')  

print(gdf.head)
# Out:
# <bound method NDFrame.head of    business_status                                               icon  \
# 0      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#    icon_background_color                                 icon_mask_base_uri  \
# 0                #4B96F3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2                #4DB546  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4                #13B5C7  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5                #4DB546  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6                #4DB546  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                              name  \
# 0                       Twin Cities Water Systems
# 1                     Water Department Management
# 2                    Xcel Energy Water Power Park
# 3                           Surge Water Treatment
# 4                          Minneapolis Water Taxi
# 5                                Water Power Park
# 6                                Water Works Park
# 7                              Clean Water Action
# 8                                      Water Laws
# 9                     NADI water charging station
# 10                         Great Waters Financial
# 11                       Save the Boundary Waters
# 12  Commercial Water Damage Minnesota Minneapolis
#
#                        place_id  rating                    reference   scope  \
# 0   ChIJmaXYl5wys1IR-qZUcdPXk-U     0.0  ChIJmaXYl5wys1IR-qZUcdPXk-U  GOOGLE
# 1   ChIJucivcZwys1IRKdixZc1RaAI     0.0  ChIJucivcZwys1IRKdixZc1RaAI  GOOGLE
# 2   ChIJ6xmCT3sts1IRK2iXrEM21OM     4.8  ChIJ6xmCT3sts1IRK2iXrEM21OM  GOOGLE
# 3   ChIJVVVVVYQys1IRU1OZryKsbLQ     0.0  ChIJVVVVVYQys1IRU1OZryKsbLQ  GOOGLE
# 4   ChIJg21GwkEzs1IRej2aDcz4slU     5.0  ChIJg21GwkEzs1IRej2aDcz4slU  GOOGLE
# 5   ChIJOZMdYXsts1IRDivkxw5AF9Y     4.7  ChIJOZMdYXsts1IRDivkxw5AF9Y  GOOGLE
# 6   ChIJz7rAb6Mts1IRfcaEd3zudiY     4.7  ChIJz7rAb6Mts1IRfcaEd3zudiY  GOOGLE
# 7   ChIJK0uwCGhUVEARZ4VvFiXu92Y     3.2  ChIJK0uwCGhUVEARZ4VvFiXu92Y  GOOGLE
# 8   ChIJIzfMopsys1IRjmEY_bA0yUI     0.0  ChIJIzfMopsys1IRjmEY_bA0yUI  GOOGLE
# 9   ChIJDVQDl-Yzs1IRTyS3yNUC1xY     0.0  ChIJDVQDl-Yzs1IRTyS3yNUC1xY  GOOGLE
# 10  ChIJZ8mSd1Q2s1IRb8CUDQQ3n10     0.0  ChIJZ8mSd1Q2s1IRb8CUDQQ3n10  GOOGLE
# 11  ChIJ2_45sR0ts1IRN9bBU0oM99w     0.0  ChIJ2_45sR0ts1IRN9bBU0oM99w  GOOGLE
# 12  ChIJ-ZDfQ40zs1IR8WWCeo22LRE     5.0  ChIJ-ZDfQ40zs1IR8WWCeo22LRE  GOOGLE
#
#                                                 types  ...  Longitude  \
# 0   [shopping_mall, point_of_interest, establishment]  ... -93.266206
# 1                  [point_of_interest, establishment]  ... -93.265841
# 2   [park, tourist_attraction, point_of_interest, ...  ... -93.254667
# 3                  [point_of_interest, establishment]  ... -93.269357
# 4   [tourist_attraction, point_of_interest, establ...  ... -93.270309
# 5   [park, tourist_attraction, point_of_interest, ...  ... -93.256595
# 6            [park, point_of_interest, establishment]  ... -93.261092
# 7                  [point_of_interest, establishment]  ... -93.263451
# 8                  [point_of_interest, establishment]  ... -93.267477
# 9          [point_of_interest, health, establishment]  ... -93.265011
# 10        [finance, point_of_interest, establishment]  ... -93.274237
# 11                 [point_of_interest, establishment]  ... -93.250098
# 12  [general_contractor, point_of_interest, establ...  ... -93.274550
#
#    geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                        44.981554                       -93.264674
# 1                        44.979880                       -93.264502
# 2                        44.984997                       -93.253295
# 3                        44.984976                       -93.267968
# 4                        44.994633                       -93.268865
# 5                        44.985219                       -93.254649
# 6                        44.982833                       -93.259803
# 7                        44.979492                       -93.262244
# 8                        44.979757                       -93.266117
# 9                        44.979130                       -93.263638
# 10                       44.981759                       -93.272702
# 11                       45.000975                       -93.248940
# 12                       44.980452                       -93.273068
#
#     geometry.viewport.southwest.lat  geometry.viewport.southwest.lng  \
# 0                         44.978855                       -93.267373
# 1                         44.977181                       -93.267202
# 2                         44.982297                       -93.255995
# 3                         44.982277                       -93.270668
# 4                         44.991933                       -93.271564
# 5                         44.982223                       -93.257349
# 6                         44.980134                       -93.262503
# 7                         44.976792                       -93.264943
# 8                         44.977057                       -93.268817
# 9                         44.976430                       -93.266338
# 10                        44.979060                       -93.275402
# 11                        44.998275                       -93.251640
# 12                        44.977753                       -93.275767
#
#     opening_hours.open_now         plus_code.compound_code  \
# 0                     True  XPJM+4G Minneapolis, Minnesota
# 1                      NaN  XPHM+8P Minneapolis, Minnesota
# 2                     True  XPMW+74 Minneapolis, Minnesota
# 3                      NaN                             NaN
# 4                      NaN  XPVH+8V Minneapolis, Minnesota
# 5                    False  XPMV+59 Minneapolis, Minnesota
# 6                      NaN  XPJQ+JH Minneapolis, Minnesota
# 7                    False  XPHP+6J Minneapolis, Minnesota
# 8                      NaN  XPHJ+9X Minneapolis, Minnesota
# 9                      NaN  XPHM+4X Minneapolis, Minnesota
# 10                   False  XPJG+48 Minneapolis, Minnesota
# 11                     NaN  XPXX+RX Minneapolis, Minnesota
# 12                    True  XPHG+J5 Minneapolis, Minnesota
#
#     plus_code.global_code                                             photos  \
# 0             86P8XPJM+4G                                                NaN
# 1             86P8XPHM+8P                                                NaN
# 2             86P8XPMW+74  [{'height': 3024, 'html_attributions': ['<a hr...
# 3                     NaN                                                NaN
# 4             86P8XPVH+8V  [{'height': 2160, 'html_attributions': ['<a hr...
# 5             86P8XPMV+59  [{'height': 1366, 'html_attributions': ['<a hr...
# 6             86P8XPJQ+JH  [{'height': 3024, 'html_attributions': ['<a hr...
# 7             86P8XPHP+6J                                                NaN
# 8             86P8XPHJ+9X                                                NaN
# 9             86P8XPHM+4X                                                NaN
# 10            86P8XPJG+48  [{'height': 680, 'html_attributions': ['<a hre...
# 11            86P8XPXX+RX                                                NaN
# 12            86P8XPHG+J5  [{'height': 1600, 'html_attributions': ['<a hr...
#
#                   geometry
# 0   POINT (44.980 -93.266)
# 1   POINT (44.978 -93.266)
# 2   POINT (44.983 -93.255)
# 3   POINT (44.984 -93.269)
# 4   POINT (44.993 -93.270)
# 5   POINT (44.983 -93.257)
# 6   POINT (44.982 -93.261)
# 7   POINT (44.978 -93.263)
# 8   POINT (44.978 -93.267)
# 9   POINT (44.978 -93.265)
# 10  POINT (44.980 -93.274)
# 11  POINT (45.000 -93.250)
# 12  POINT (44.979 -93.275)
#
# [13 rows x 23 columns]>

# %% [markdown]
# ### Rectify Coordinate Systems

# %%
# Read shapefile data
infested_waters = gpd.read_file("/home/sauer326/5571 Labs/env_listed_infested_waters.shp")

# View the coordinate reference system of both layers 
print(infested_waters.crs)
print(gdf.crs)
# Out:
# epsg:26915
# epsg:26915

# %% [markdown]
# ### Perform Spatial Join

# %%
# Use Geopandas spatial join to combine two datasets
joined_data = gpd.sjoin(infested_waters, 
                         gdf, 
                         how="inner")
